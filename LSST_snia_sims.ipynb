# %% [markdown]
# # LSST SN Ia Simulation Pipeline
#
# Forward-model SN Ia light curves with the Rubin/LSST 10-year baseline cadence using `lightcurvelynx`.
#
# **Survey**: LSST baseline v5.3.0 OpSim (`baseline_v5.3.0_10yrs.db`)
# **Model**: SALT3 via `SncosmoWrapperModel`
# **Filters**: u, g, r, i, z, y
# **Redshift**: volumetric rate (Frohmaier et al. 2019), z = 0.01–1.2
# **Parameters**: Gaussian priors for x1 and c (no pzflow, no host galaxy)

# %% [markdown]
# ## 1. Imports

# %% [markdown]
# ## 0. Environment Setup
#
# No need to set `LIGHTCURVELYNX_DATA_DIR` — the default cache at `~/.cache/lightcurvelynx` is used.
# The OpSim v5.3.0 database is already downloaded there.

# %%
# auto reload
# %load_ext autoreload
# %autoreload 2

# %%
from lightcurvelynx import _LIGHTCURVELYNX_DOWNLOAD_DATA_DIR
print(f"Data dir: {_LIGHTCURVELYNX_DOWNLOAD_DATA_DIR}")
# Out:
# Data dir: /Users/mi/.cache/lightcurvelynx

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

from lightcurvelynx.obstable.opsim import OpSim
from lightcurvelynx.astro_utils.passbands import PassbandGroup
from lightcurvelynx.astro_utils.snia_utils import (
    DistModFromRedshift,
    X0FromDistMod,
    num_snia_per_redshift_bin,
    snia_volumetric_rates,
)
from lightcurvelynx.math_nodes.np_random import NumpyRandomFunc
from lightcurvelynx.math_nodes.scipy_random import SamplePDF
from lightcurvelynx.math_nodes.ra_dec_sampler import ObsTableUniformRADECSampler,ApproximateMOCSampler
from lightcurvelynx.models.sncosmo_models import SncosmoWrapperModel
from lightcurvelynx.simulate import simulate_lightcurves
from lightcurvelynx.utils.extrapolate import LinearDecayOnMag,ZeroPadding

# %% [markdown]
# ## 2. Simulation Configuration

# %%
SEED = 1024
RNG  = np.random.default_rng(SEED)

SIM_PARAMS = {
    # Cosmology
    "H0": 70.0,
    "Omega_m": 0.315,
    "w": -1.0,
    # Redshift range
    "zmin": 0.001,
    "zmax": 0.7,
    "znbins": 100,
    # Tripp relation coefficients
    "alpha": 0.15,
    "beta": 3.15,
    # SALT3 Gaussian priors (no pzflow, no host galaxy)
    "x1_mean": 0.973,  "x1_sigma_minus": 1.472, "x1_sigma_plus": 0.222,
    "c_mean":  -0.054,  "c_sigma_minus":  0.043, "c_sigma_plus":  0.101,
    "m_abs_mean": -19.3, "m_abs_sigma": 0.1,
    # Survey
    "filters": ["u", "g", "r", "i", "z", "y"],
    "sky_coverage": 18_000.0,  # placeholder; overwritten from opsim
}

# %% [markdown]
# ## 3. Load LSST OpSim
#
# The file is downloaded once and cached locally by `OpSim.from_url()`.

# %%
opsim_path = _LIGHTCURVELYNX_DOWNLOAD_DATA_DIR / "opsim" / "baseline_v5.3.0_10yrs.db"
opsim = OpSim.from_db(opsim_path)
print(f"OpSim loaded: {len(opsim):,} observations")
print(f"MJD range: {opsim['time'].min():.1f} – {opsim['time'].max():.1f}")
print(f"Filters:    {sorted(opsim['filter'].unique())}")
# Out:
# OpSim loaded: 1,844,571 observations
# MJD range: 61208.2 – 64860.4
# Filters:    ['g', 'i', 'r', 'u', 'y', 'z']

# %%
sky_coverage = opsim.estimate_coverage()    
# sky_coverage = 75
SIM_PARAMS["sky_coverage"] = sky_coverage
print(f"Estimated sky coverage: {sky_coverage:.0f} deg²")
# Out:
# Estimated sky coverage: 28148 deg²

# %% [markdown]
# ## 4. Calculate Number of SNe to Simulate
#
# Integrate the volumetric SN Ia rate over the survey volume and duration:
# $$N = \int_{z_{\rm min}}^{z_{\rm max}} r_v(z)\,\frac{dV}{dz}\,\frac{dz}{1+z} \times \Omega \times T_{\rm survey}$$

# %%
t_min = float(opsim["time"].min())
t_max = float(opsim["time"].max())
SIM_PARAMS["tmin"] = t_min
SIM_PARAMS["tmax"] = t_max

survey_length = (t_max - t_min) / 365.25
print(f"Survey length = {survey_length:.2f} years")

solid_angle = SIM_PARAMS["sky_coverage"] * (np.pi / 180.0) ** 2
print(f"Solid angle   = {solid_angle:.4f} sr  ({SIM_PARAMS['sky_coverage']:,.0f} deg²)")

nsntotal, _ = num_snia_per_redshift_bin(
    SIM_PARAMS["zmin"],
    SIM_PARAMS["zmax"],
    znbins=1,
    solid_angle=solid_angle,
    vol_rate_function=snia_volumetric_rates,
    H0=SIM_PARAMS["H0"],
    Omega_m=SIM_PARAMS["Omega_m"],
)
nsn = int(nsntotal[0] * survey_length)
print(f"Expected SNe Ia = {nsn:,}")

nsn = int(nsn * 0.01)
print(f"Expected SNe Ia (10%) = {nsn:,}")
# Out:
# Survey length = 10.00 years
# Solid angle   = 8.5743 sr  (28,148 deg²)
# Expected SNe Ia = 13,286,457
# Expected SNe Ia (10%) = 1,328,645

# %% [markdown]
# ## 5. Load LSST Passbands

# %%
passbands = PassbandGroup.from_preset("LSST", filters=SIM_PARAMS["filters"])
print(passbands)
# Out:
# PassbandGroup containing 6 passbands: LSST_u, LSST_g, LSST_r, LSST_i, LSST_z, LSST_y

# %% [markdown]
# ## 6. Redshift Distribution (Volumetric Rate)
#
# Use the Frohmaier et al. (2019) volumetric rate $r_v(z) = r_0\,(1+z)^\alpha$ to compute the
# expected number of SNe Ia per redshift bin, then build an interpolated PDF for sampling.

# %%
nsn_per_bin, z_mean = num_snia_per_redshift_bin(
    SIM_PARAMS["zmin"],
    SIM_PARAMS["zmax"],
    SIM_PARAMS["znbins"],
    H0=SIM_PARAMS["H0"],
    Omega_m=SIM_PARAMS["Omega_m"],
)
zpdf = interp1d(z_mean, nsn_per_bin, bounds_error=False, fill_value=0)

fig, ax = plt.subplots(figsize=(7, 4))
dz = (SIM_PARAMS["zmax"] - SIM_PARAMS["zmin"]) / SIM_PARAMS["znbins"]
ax.bar(z_mean, nsn_per_bin, width=dz, color="steelblue", alpha=0.8)
ax.set(xlabel="Redshift", ylabel="SN Ia yr$^{-1}$ per bin",
       title="Volumetric rate redshift distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Build SN Ia Source Model
#
# Parameter graph:
# - **RA, Dec** — uniformly sampled from the observed LSST footprint (`ObsTableUniformRADECSampler`)
# - **redshift** — drawn from the volumetric rate PDF (`SamplePDF`)
# - **x1** — AsymmetricGaussian($\mu=0.973$, $\sigma_-=1.472$, $\sigma_+=0.222$)
# - **c** — AsymmetricGaussian($\mu=-0.054$, $\sigma_-=0.043$, $\sigma_+=0.101$)
# - **M_abs** — Gaussian($\mu=-19.3$, $\sigma=0.1$)
# - **distmod** — computed from redshift via `DistModFromRedshift`
# - **x0** — computed via the Tripp relation through `X0FromDistMod`

# %%
# RA/Dec: uniform over the opsim footprint (rejection sampling)
# radec = ObsTableUniformRADECSampler(opsim, node_label="radec")
moc = opsim.build_moc(max_depth=12)
radec = ApproximateMOCSampler(moc, node_label="radec")

# Redshift from volumetric rate PDF
z_func = SamplePDF(zpdf, node_label="redshift")

# Asymmetric Gaussian SALT3 parameter priors
def asymmetric_gaussian_pdf(x, mu, sigma_minus, sigma_plus):
    norm_factor = np.sqrt(2 / np.pi) / (sigma_minus + sigma_plus)
    return np.where(
        x < mu,
        norm_factor * np.exp(-0.5 * ((x - mu) / sigma_minus) ** 2),
        norm_factor * np.exp(-0.5 * ((x - mu) / sigma_plus) ** 2),
    )
def x1_pdf(x):
    return asymmetric_gaussian_pdf(x, SIM_PARAMS["x1_mean"], SIM_PARAMS["x1_sigma_minus"], SIM_PARAMS["x1_sigma_plus"])
def c_pdf(c):
    return asymmetric_gaussian_pdf(c, SIM_PARAMS["c_mean"], SIM_PARAMS["c_sigma_minus"], SIM_PARAMS["c_sigma_plus"])

x1_func = SamplePDF(x1_pdf, node_label="x1")
c_func = SamplePDF(c_pdf, node_label="c")
m_abs_func = NumpyRandomFunc("normal", loc=SIM_PARAMS["m_abs_mean"], scale=SIM_PARAMS["m_abs_sigma"])

# x0 via Tripp relation
distmod_func = DistModFromRedshift(
    z_func, H0=SIM_PARAMS["H0"], Omega_m=SIM_PARAMS["Omega_m"]
)
x0_func = X0FromDistMod(
    distmod=distmod_func,
    x1=x1_func,
    c=c_func,
    alpha=SIM_PARAMS["alpha"],
    beta=SIM_PARAMS["beta"],
    m_abs=m_abs_func,
    node_label="x0_func",
)

# Extrapolation settings
time_extrap_before = ZeroPadding()
time_extrap_after = LinearDecayOnMag(decay_rate=0.02, mag_thres=30.)
wave_extrap_before = ZeroPadding()
wave_extrap_after = ZeroPadding()

# Assemble the SALT3 source (no host galaxy)
source = SncosmoWrapperModel(
    "salt3",
    t0=NumpyRandomFunc("uniform", low=t_min, high=t_max),
    x0=x0_func,
    x1=x1_func,
    c=c_func,
    ra=radec.ra,
    dec=radec.dec,
    redshift=z_func,
    node_label="source",
    time_extrapolation=(time_extrap_before,time_extrap_after),
    wave_extrapolation=(wave_extrap_before,wave_extrap_after),  
)
print("Source model built successfully.")
# Out:
# Source model built successfully.

# %% [markdown]
# ## 8. Run Simulation

# %%
opsim.columns
# Out:
# Index(['observationId', 'ra', 'dec', 'time', 'flush_by_mjd', 'exptime', 'band',
#        'filter', 'rotation', 'rotSkyPos_desired', 'nexposure', 'airmass',
#        'seeingFwhm500', 'seeing', 'seeingFwhmGeom', 'skybrightness', 'night',
#        'slewTime', 'visitTime', 'slewDistance', 'maglim', 'altitude',
#        'azimuth', 'paraAngle', 'pseudoParaAngle', 'cloud', 'moonAlt', 'sunAlt',
#        'scheduler_note', 'target_name', 'target_id', 'observationStartLST',
#        'rotTelPos', 'rotTelPos_backup', 'moonAz', 'sunAz', 'sunRA', 'sunDec',
#        'moonRA', 'moonDec', 'moonDistance', 'solarElong', 'moonPhase',
#        'cummTelAz', 'observation_reason', 'science_program',
#        'cloud_extinction', 'zp', 'psf_footprint', 'sky_bg_e'],
#       dtype='object')

# %%
param_cols = [
    "source.t0",
    "source.x0",
    "source.x1",
    "source.c",
    "source.redshift",
    "source.ra",
    "source.dec",
    "x0_func.distmod",
]
obstable_save_cols = ["zp"]

parallel_executor = "loky"  # Options: "loky", "dask", None
if parallel_executor == "loky":
    try:
        import loky
        executor = loky.get_reusable_executor(max_workers=4)
        results = simulate_lightcurves(
            model=source,
            num_samples=nsn,
            survey_info=opsim,
            passbands=passbands,
            param_cols=param_cols,
            obstable_save_cols=obstable_save_cols,
            rng=RNG,
            num_jobs=4,
            batch_size=2000,
            executor=executor,
        )
    except ImportError:
        print("Loky is not installed")
elif parallel_executor == "dask":
    try:
        import dask.distributed

        with dask.distributed.Client() as client:
            print(f"Dask dashboard link: {client.dashboard_link}")
            results = simulate_lightcurves(
                model=source,
                num_samples=nsn,
                survey_info=opsim,
                passbands=passbands,
                param_cols=param_cols,
                obstable_save_cols=obstable_save_cols,
                rng=RNG,
                num_jobs=4,
                batch_size=2000,
                executor=client,
            )
    except ImportError:
        print("Dask is not installed")
else:
    executor = None
    results = simulate_lightcurves(
        model=source,
        num_samples=nsn,
        survey_info=opsim,
        passbands=passbands,
        param_cols=param_cols,
        obstable_save_cols=obstable_save_cols,
        rng=RNG,
        num_jobs=4,
        batch_size=2000,
        executor=executor,
    )
print(f"Generated {len(results)} light curves")
print(results["lightcurve"][0])

print(f"Simulated {len(results):,} SNe Ia")
results.head()
# Out:
# /Users/mi/Work/lightcurvelynx/lightcurvelynx/src/lightcurvelynx/simulate.py:681: FutureWarning: The passbands argument is deprecated and will be removed from future versions.
#   warnings.warn(
# /Users/mi/Work/lightcurvelynx/lightcurvelynx/src/lightcurvelynx/simulate.py:693: FutureWarning: Passing ObsTable objects directly in survey_info is deprecated and will be removed in future versions. Please use SurveyInfo objects instead.
#   warnings.warn(
# Simulating:   0%|          | 0/2000 [00:00<?, ?obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 281.33obj/s]
# Simulating:  71%|███████   | 1422/2000 [00:04<00:01, 321.78obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 298.87obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 287.26obj/s]
# Simulating:  95%|█████████▍| 1894/2000 [00:06<00:00, 304.73obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 272.85obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 306.35obj/s]
# Simulating:  40%|███▉      | 794/2000 [00:02<00:04, 280.33obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 284.77obj/s]s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 296.84obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating:  35%|███▌      | 700/2000 [00:02<00:04, 318.09obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 293.10obj/s]
# Simulating:  96%|█████████▌| 1910/2000 [00:06<00:00, 296.22obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 286.83obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 323.62obj/s]
# Simulating:  57%|█████▋    | 1142/2000 [00:04<00:02, 319.19obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 286.48obj/s]
# Simulating:  58%|█████▊    | 1154/2000 [00:03<00:02, 294.13obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 286.95obj/s]
# Simulating:   6%|▌         | 116/2000 [00:00<00:06, 269.20obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 282.07obj/s]
# Simulating:  94%|█████████▎| 1872/2000 [00:06<00:00, 243.30obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 276.00obj/s]
# Simulating:   5%|▍         | 92/2000 [00:00<00:07, 252.27obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 303.40obj/s]ing:  73%|███████▎  | 1468/2000 [00:04<00:01, 296.38obj/s]
# Simulating:  93%|█████████▎| 1869/2000 [00:06<00:00, 259.59obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 283.12obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 322.44obj/s]s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 310.32obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 295.25obj/s]]
# Simulating:  64%|██████▍   | 1287/2000 [00:04<00:02, 288.38obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 297.81obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 316.86obj/s]
# Simulating:  27%|██▋       | 535/2000 [00:01<00:04, 327.16obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 296.50obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 277.15obj/s]
# Simulating:  25%|██▌       | 504/2000 [00:01<00:04, 350.10obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 302.67obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 286.07obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 311.20obj/s]s]
# Simulating:  66%|██████▌   | 1318/2000 [00:04<00:02, 321.66obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 321.88obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 310.09obj/s]
# Simulating:  81%|████████  | 1618/2000 [00:05<00:01, 287.94obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 285.71obj/s]
# Simulating:   5%|▌         | 107/2000 [00:00<00:06, 275.08obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 304.28obj/s]
# Simulating:  72%|███████▏  | 1433/2000 [00:04<00:01, 335.90obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 292.52obj/s]
# Simulating:  98%|█████████▊| 1961/2000 [00:06<00:00, 277.59obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 294.59obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 281.20obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 294.80obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 309.54obj/s]
# Simulating:  44%|████▍     | 876/2000 [00:02<00:03, 317.42obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 268.02obj/s]
# Simulating:   5%|▌         | 109/2000 [00:00<00:07, 266.43obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 268.09obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 263.57obj/s]
# Simulating:   2%|▏         | 46/2000 [00:00<00:08, 221.70obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 287.93obj/s]
# Simulating:  35%|███▌      | 708/2000 [00:02<00:05, 236.40obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 309.47obj/s]
# Simulating:  65%|██████▌   | 1301/2000 [00:04<00:02, 238.52obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 270.41obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 303.75obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 260.90obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 284.24obj/s]
# Simulating:  29%|██▉       | 576/2000 [00:02<00:05, 237.34obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 295.09obj/s]
# Simulating:  56%|█████▌    | 1110/2000 [00:03<00:02, 309.04obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 294.36obj/s]
# Simulating:  76%|███████▌  | 1523/2000 [00:04<00:01, 299.36obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 304.89obj/s]
# Simulating:  48%|████▊     | 954/2000 [00:03<00:03, 310.67obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 304.96obj/s]
# Simulating:  41%|████      | 818/2000 [00:02<00:03, 313.65obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 284.61obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 306.35obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 297.07obj/s]
# Simulating:  74%|███████▎  | 1471/2000 [00:04<00:01, 312.05obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 317.60obj/s]
# Simulating: 100%|████��█████| 2000/2000 [00:06<00:00, 287.47obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 304.86obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 285.67obj/s]
# Simulating:  61%|██████    | 1212/2000 [00:04<00:02, 326.08obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 279.04obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 285.21obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 300.42obj/s]]
# Simulating:  62%|██████▏   | 1234/2000 [00:04<00:02, 341.33obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 275.44obj/s]
# Simulating:  75%|███████▍  | 1498/2000 [00:04<00:01, 346.33obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 290.85obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 279.23obj/s]
# Simulating:  21%|██▏       | 426/2000 [00:01<00:05, 311.00obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 292.62obj/s]
# Simulating:  14%|█▎        | 274/2000 [00:00<00:06, 278.25obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 277.18obj/s]
# Simulating:  41%|████▏     | 829/2000 [00:02<00:03, 309.17obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 290.87obj/s]0:00, 257.70obj/s]
# Simulating:  66%|██████▌   | 1310/2000 [00:04<00:02, 308.07obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 304.94obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 262.18obj/s]
# Simulating:  12%|█▏        | 243/2000 [00:00<00:06, 279.50obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 271.76obj/s]
# Simulating:  61%|██████    | 1215/2000 [00:04<00:02, 329.73obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 281.94obj/s]
# Simulating:  82%|████████▏ | 1647/2000 [00:05<00:01, 322.09obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 276.72obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 284.45obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|████��█████| 2000/2000 [00:06<00:00, 294.93obj/s]
# Simulating:  56%|█████▌    | 1120/2000 [00:03<00:02, 356.43obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 310.41obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 301.62obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating:  45%|████▌     | 903/2000 [00:02<00:03, 313.70obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 275.50obj/s]
# Simulating:  26%|██▌       | 517/2000 [00:01<00:04, 326.06obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 281.31obj/s]
# Simulating:  85%|████████▌ | 1703/2000 [00:05<00:01, 241.91obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 315.45obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 282.43obj/s]
# Simulating:  19%|█▊        | 371/2000 [00:01<00:06, 240.19obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 282.25obj/s]
# Simulating:  80%|████████  | 1608/2000 [00:05<00:01, 350.95obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 298.09obj/s]
# Simulating:  84%|████████▍ | 1680/2000 [00:05<00:01, 284.53obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 318.41obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 287.27obj/s]]
# Simulating:  52%|█████▏    | 1048/2000 [00:03<00:02, 340.28obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 270.56obj/s]
# Simulating:  14%|█▎        | 273/2000 [00:01<00:06, 247.20obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 314.57obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 306.83obj/s]
# Simulating:  30%|██▉       | 590/2000 [00:01<00:04, 338.37obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 297.65obj/s]
# Simulating:  76%|███████▋  | 1527/2000 [00:05<00:01, 370.54obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 294.96obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 285.33obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 282.81obj/s]
# Simulating:  41%|████▏     | 827/2000 [00:02<00:03, 328.81obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 297.63obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 282.17obj/s]
# Simulating:   8%|▊         | 160/2000 [00:00<00:06, 285.97obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 287.86obj/s]
# Simulating:  40%|████      | 810/2000 [00:02<00:03, 314.37obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 295.14obj/s]
# Simulating:   3%|▎         | 60/2000 [00:00<00:06, 296.16obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 257.40obj/s]
# Simulating:  48%|████▊     | 950/2000 [00:03<00:03, 304.80obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 266.81obj/s]
# Simulating:  15%|█▍        | 298/2000 [00:01<00:06, 265.70obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 271.28obj/s]
# Simulating:  25%|██▌       | 504/2000 [00:01<00:05, 281.25obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 305.52obj/s]
# Simulating:  17%|█▋        | 334/2000 [00:01<00:05, 280.29obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 290.27obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 312.38obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 287.20obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 291.72obj/s]
# Simulating:   9%|▊         | 174/2000 [00:00<00:07, 245.26obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:08<00:00, 242.33obj/s]
# Simulating:  48%|████▊     | 950/2000 [00:03<00:03, 296.68obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 275.24obj/s]
# Simulating:  51%|█████▏    | 1027/2000 [00:03<00:03, 288.07obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 288.05obj/s]
# Simulating:  14%|█▎        | 273/2000 [00:01<00:06, 274.90obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 300.14obj/s]
# Simulating:  33%|███▎      | 657/2000 [00:01<00:04, 324.35obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 290.35obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 266.92obj/s]
# Simulating:   6%|▌         | 113/2000 [00:00<00:06, 280.01obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 271.91obj/s]
# Simulating:  74%|███████▍  | 1476/2000 [00:05<00:01, 274.11obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 281.74obj/s]
# Simulating:  43%|████▎     | 857/2000 [00:02<00:04, 235.39obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 281.71obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 303.05obj/s]
# Simulating:  10%|█         | 210/2000 [00:00<00:06, 257.17obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 277.63obj/s]
# Simulating:  69%|██████▉   | 1382/2000 [00:04<00:01, 342.16obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 288.64obj/s]
# Simulating:  87%|████████▋ | 1738/2000 [00:05<00:00, 326.37obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 304.00obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 280.55obj/s]
# Simulating:  60%|██████    | 1208/2000 [00:03<00:02, 361.91obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 316.55obj/s]
# Simulating:   3%|▎         | 55/2000 [00:00<00:07, 273.23obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 284.96obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 283.52obj/s]
# Simulating:  51%|█████     | 1017/2000 [00:03<00:03, 304.80obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 277.35obj/s]
# Simulating:  25%|██▍       | 492/2000 [00:01<00:04, 303.59obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 290.96obj/s]
# Simulating:  76%|███████▌  | 1513/2000 [00:05<00:01, 292.93obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 281.32obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 305.93obj/s]
# Simulating:  33%|███▎      | 652/2000 [00:02<00:04, 307.83obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 298.93obj/s]
# Simulating:  34%|███▍      | 687/2000 [00:02<00:04, 299.00obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 263.27obj/s]
# Simulating:  55%|█████▌    | 1107/2000 [00:03<00:02, 309.73obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 305.24obj/s]
# Simulating:  74%|███████▎  | 1474/2000 [00:04<00:01, 354.45obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 292.44obj/s]
# Simulating:  71%|███████   | 1424/2000 [00:04<00:02, 278.91obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 283.73obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 274.22obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 260.48obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 305.11obj/s]
# Simulating:  42%|████▏     | 844/2000 [00:03<00:04, 282.59obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 268.41obj/s]
# Simulating:  41%|████      | 822/2000 [00:02<00:04, 290.79obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 288.11obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 313.81obj/s]
# Simulating:   3%|▎         | 53/2000 [00:00<00:07, 261.97obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating:  20%|█▉        | 397/2000 [00:01<00:05, 304.70obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 290.06obj/s]
# Simulating:  32%|███▏      | 644/2000 [00:02<00:04, 306.49obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 276.36obj/s]
# Simulating:  42%|████▏     | 839/2000 [00:02<00:03, 332.39obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 308.75obj/s]
# Simulating:  74%|███████▎  | 1474/2000 [00:05<00:01, 295.49obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 292.34obj/s]
# Simulating:  69%|██████▉   | 1381/2000 [00:04<00:02, 248.84obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 283.97obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 321.11obj/s]
# Simulating:  48%|████▊     | 954/2000 [00:03<00:03, 295.00obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 268.52obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 282.58obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 276.18obj/s]s]
# Simulating:  15%|█▌        | 307/2000 [00:01<00:05, 283.13obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 261.44obj/s]
# Simulating:  98%|█████████▊| 1965/2000 [00:07<00:00, 265.20obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 275.78obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 312.62obj/s]
# Simulating:  80%|███████▉  | 1594/2000 [00:05<00:01, 313.85obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 285.30obj/s]
# Simulating:  67%|██████▋   | 1343/2000 [00:04<00:02, 289.42obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 300.79obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 275.61obj/s]
# Simulating:  40%|███▉      | 795/2000 [00:03<00:04, 295.66obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 280.00obj/s]
# Simulating:  68%|██████▊   | 1356/2000 [00:04<00:01, 332.13obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 271.22obj/s]
# Simulating:  58%|█████▊    | 1159/2000 [00:04<00:02, 299.52obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 270.67obj/s]
# Simulating:   4%|▍         | 84/2000 [00:00<00:06, 277.84obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 285.40obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 279.99obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 293.76obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 307.95obj/s]
# Simulating:  54%|█████▍    | 1082/2000 [00:04<00:03, 240.03obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 259.36obj/s]
# Simulating:  59%|█████▉    | 1180/2000 [00:04<00:02, 274.21obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 285.38obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 316.30obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 276.40obj/s]
# Simulating:   1%|          | 24/2000 [00:00<00:08, 232.03obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 313.17obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 302.60obj/s]
# Simulating:  44%|████▍     | 880/2000 [00:03<00:03, 329.88obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 282.54obj/s]
# Simulating:  60%|█████▉    | 1199/2000 [00:04<00:02, 309.25obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 283.28obj/s]
# Simulating:  97%|█████████▋| 1949/2000 [00:06<00:00, 262.93obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 284.86obj/s]
# Simulating:  29%|██▊       | 574/2000 [00:01<00:03, 360.66obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 311.06obj/s]
# Simulating:  42%|████▏     | 834/2000 [00:02<00:03, 316.81obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 280.38obj/s]
# Simulating:  27%|██▋       | 542/2000 [00:01<00:04, 293.88obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 302.35obj/s]
# Simulating:  50%|████▉     | 997/2000 [00:03<00:02, 337.72obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 276.37obj/s]
# Simulating:  47%|████▋     | 948/2000 [00:03<00:03, 325.28obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 275.65obj/s]
# Simulating:  44%|████▎     | 873/2000 [00:02<00:04, 277.32obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 283.21obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 287.21obj/s]
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 270.47obj/s]
# /Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 297.25obj/s]
# Simulating:  83%|████████▎ | 1651/2000 [00:05<00:01, 323.12obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 302.63obj/s]
# Simulating:  64%|██████▍   | 1287/2000 [00:04<00:02, 240.01obj/s]/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Simulating: 100%|██████████| 2000/2000 [00:07<00:00, 267.34obj/s]
# Simulating:  59%|█████▉    | 1178/2000 [00:03<00:02, 293.89obj/s]Exception in thread ExecutorManagerThread:
# Traceback (most recent call last):
#   File "/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
# Simulating:  67%|██████▋   | 1343/2000 [00:04<00:02, 310.74obj/s]
#     self.run()
#   File "/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py", line 626, in run
#     self.terminate_broken(bpe)
#   File "/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py", line 826, in terminate_broken
#     work_item.future.set_exception(bpe)
#   File "/Users/mi/anaconda3/envs/lightcurvelynx/lib/python3.11/concurrent/futures/_base.py", line 559, in set_exception
#     raise InvalidStateError('{}: {!r}'.format(self._state, self))
# concurrent.futures._base.InvalidStateError: CANCELLED: <Future at 0x40bb58c10 state=cancelled>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 18
#      16     import loky
#      17     executor = loky.get_reusable_executor(max_workers=4)
# ---> 18     results = simulate_lightcurves(
#      19         model=source,
#      20         num_samples=nsn,
#      21         survey_info=opsim,
#      22         passbands=passbands,
#      23         param_cols=param_cols,
#      24         obstable_save_cols=obstable_save_cols,
#      25         rng=RNG,
#      26         num_jobs=4,
#      27         batch_size=2000,
#      28         executor=executor,
#      29     )
#      30 except ImportError:
#      31     print("Loky is not installed")
#
# File ~/Work/lightcurvelynx/lightcurvelynx/src/lightcurvelynx/simulate.py:755, in simulate_lightcurves(model, num_samples, survey_info, passbands, obstable_save_cols, param_cols, obs_time_window_offset, rest_time_window_offset, apply_saturation, output_file_path, rng, executor, num_jobs, batch_size, save_full_filter_names, progress_bar)
#     753 # If we have an executor, use that.
#     754 if executor is not None:
# --> 755     result_list = _simulate_lightcurves_parallel(simulation_info, executor, batch_size=batch_size)
#     756 else:
#     757     with concurrent.futures.ProcessPoolExecutor(max_workers=num_jobs) as executor:
#
# File ~/Work/lightcurvelynx/lightcurvelynx/src/lightcurvelynx/simulate.py:570, in _simulate_lightcurves_parallel(simulation_info, executor, batch_size)
#     568 futures_or_results = executor.map(_simulate_lightcurves_batch, batches)
#     569 result_list = []
# --> 570 for res in futures_or_results:
#     571     if hasattr(res, "result") and callable(res.result):  # A Future
#     572         result_list.append(res.result())
#
# File ~/anaconda3/envs/lightcurvelynx/lib/python3.11/site-packages/loky/process_executor.py:997, in _chain_from_iterable_of_lists(iterable)
#     991 def _chain_from_iterable_of_lists(iterable):
#     992     """
#     993     Specialized implementation of itertools.chain.from_iterable.
#     994     Each item in *iterable* should be a list.  This function is
#     995     careful not to keep references to yielded objects.
#     996     """
# --> 997     for element in iterable:
#     998         element.reverse()
#     999         while element:
#
# File ~/anaconda3/envs/lightcurvelynx/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/anaconda3/envs/lightcurvelynx/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/anaconda3/envs/lightcurvelynx/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/envs/lightcurvelynx/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
# Simulating: 100%|██████████| 2000/2000 [00:06<00:00, 315.68obj/s]

# %% [markdown]
# ## 9. Apply Selection Cuts
#
# Apply detection, saturation, and quality cuts to the simulated light curves.

# %%
# Drop light curves with no observations
lightcurves = results.dropna(subset=['lightcurve'])

# Compute SNR and detection flag
lightcurves['lightcurve.snr'] = lightcurves['lightcurve.flux'] / lightcurves['lightcurve.fluxerr']
detection_snr_thres = 5.0
lightcurves['lightcurve.detection_flag'] = lightcurves['lightcurve.snr'] > detection_snr_thres

# Drop saturated observations
lightcurves_after_drop_sat = lightcurves.query("lightcurve.is_saturated == False").dropna(subset=['lightcurve'])

# Apply detection cut
print("Before detection cut: nsn =", len(lightcurves))
lightcurves_after_detection = lightcurves_after_drop_sat.query("lightcurve.detection_flag == True").dropna(subset=['lightcurve'])
print("After detection cut:  nsn =", len(lightcurves_after_detection))

# Quality cuts: >=7 unique phases in [-10, 40] days, >=2 pre-peak, >=3 post-peak, >=2 bands
def lc_quality_cuts(flux, mjd, filter, z, t0,
                    n_phases=7, n_before_peak=2, n_after_peak=3, n_bands=2):
    phases = np.floor((mjd - t0) / (1.0 + z))
    unique_phases, unique_idx = np.unique(phases, return_index=True)
    good_idx = (unique_phases >= -10) & (unique_phases <= 40)
    if np.sum(good_idx) == 0:
        return {"pass_quality_cuts": False}
    pass_cut = len(unique_phases[good_idx]) >= n_phases
    pass_cut &= np.sum(unique_phases[good_idx] < 0) >= n_before_peak
    pass_cut &= np.sum(unique_phases[good_idx] > 0) >= n_after_peak
    pass_cut &= len(np.unique(filter[unique_idx][good_idx])) >= n_bands
    return {"pass_quality_cuts": pass_cut}

pass_quality_cut = lightcurves_after_detection.reduce(
    lc_quality_cuts,
    "lightcurve.flux", "lightcurve.mjd", "lightcurve.filter", "z", "t0",
)
idx = pass_quality_cut.query("pass_quality_cuts == True").index
lightcurves_after_quality_cut = lightcurves_after_detection.loc[idx]
print("After quality cuts:   nsn =", len(lightcurves_after_quality_cut))

lightcurves["pass_quality_cuts"] = False
lightcurves.loc[idx, "pass_quality_cuts"] = True

# %% [markdown]
# ## 10. Diagnostics
#
# Quick sanity checks on the simulated population.

# %%
# redshift distribution of simulated SNe (post-cuts)
fig, ax = plt.subplots()
lightcurves_after_quality_cut["source_redshift"].hist(bins=50, ax=ax)
ax.set(xlabel="Redshift", ylabel="Count", title="Simulated redshift distribution (after selection cuts)")
plt.show()

# %%
# x1 and c distributions (post-cuts)
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
lightcurves_after_quality_cut["source_x1"].hist(bins=50, ax=axes[0])
axes[0].set(xlabel="x1", ylabel="Count")
lightcurves_after_quality_cut["source_c"].hist(bins=50, ax=axes[1])
axes[1].set(xlabel="c", ylabel="Count")
plt.tight_layout()
plt.show()

# %%
# example light curve for a single SN (post-cuts)
sn = lightcurves_after_quality_cut.iloc[np.random.choice(len(lightcurves_after_quality_cut))]
lc = sn["lightcurve"]
for band in SIM_PARAMS["filters"]:
    mask = lc["filter"] == band
    mask &= (lc["mjd"] - sn["source_t0"]) / (1.0 + sn["source_redshift"]) > -20
    mask &= (lc["mjd"] - sn["source_t0"]) / (1.0 + sn["source_redshift"]) < 100
    if mask.any():
        plt.errorbar(lc["mjd"][mask], lc["flux"][mask], lc["fluxerr"][mask],
                     fmt="o", label=band, capsize=3)
plt.axvline(sn["source_t0"], ls="--", color="k", label="t0")
plt.legend()
plt.xlabel("MJD")
plt.ylabel("Flux (nJy)")
plt.title(f'Example SN Ia  z={sn["source_redshift"]:.3f}')
plt.show()

# %% [markdown]
# ## 11. Save Results

# %%
# save results
output_path = "output/lsst_snia_results.parquet"
output_path = Path(output_path)
output_path.parent.mkdir(exist_ok=True)
results.to_parquet(output_path)
print(f"Saved to {output_path}")
